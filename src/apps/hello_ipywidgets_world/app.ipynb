# %%
import panel as pn
# Needed for Jupyter Notebook
# Add comms='colab', comms='vscode' or comms='ipywidgets' to support other notebook environments
pn.extension()

# %%
app = pn.pane.Markdown("# Hello Ipywidgets World from .pynb Notebook File")
app.servable()
# Out:
# Markdown(str)
