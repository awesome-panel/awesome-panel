# %%
from gallery.bootstrap_dashboard.main import main

# %%
main()
# Out:
# BootstrapDashboardTemplate
#     [app] Column(sizing_mode='stretch_width')
#         [0] Row(css_classes=['header'], height=58, sizing_mode='stretch_width')
#             [0] Row(width=200)
#                 [0] HSpacer()
#                 [1] Markdown(str, css_classes=['app-title'])
#                 [2] HSpacer()
#             [1] HSpacer()
#         [1] Row(css_classes=['mid'])
#             [0] Column(css_classes=['sidebar'], height_policy='max', width=200)
#                 [0] HSpacer(height=15)
#                 [1] NavigationMenu(sizing_mode='stretch_width')
#                     [0] SubHeader(str, sizing_mode='stretch_width', style={'text-align': 'center', ...})
#                     [1] NavigationButton(css_classes=['navigation', ...], name=' About')
#                     [2] NavigationButton(css_classes=['navigation', ...], name=' Dashboard')
#                     [3] NavigationButton(css_classes=['navigation', ...], name=' Plotly')
# ...
